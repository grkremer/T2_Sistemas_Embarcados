# %%
from PIL import Image, ImageFilter
import glob

# %%
print(glob.glob("*"))
# Out:
# ['Edge_Sample.png', 'imageprocess.ipynb', 'Sample.png']

# %%
def processaImagem(name):
    image = Image.open(name)
    image = image.convert("L")
    image = image.filter(ImageFilter.FIND_EDGES)
    image.save(r"Edge_Sample.png")
    return

# %%
processaImagem("Imagens/" + "Sample.png")
# Out:
# <PIL.Image.Image image mode=L size=640x509>
